# %%
n = ...
# p4为p去除0的剩余位
p4 = ... >> 900
# pbits为原位数
pbits = 2048
kbits = pbits - p4.nbits()
print(p4.nbits())
p4 = p4 << kbits
PR.<x> = PolynomialRing(Zmod(n))
f = x + p4
roots = f.small_roots(X=2^kbits, beta=0.4)
if roots:        
    p = p4+int(roots[0]) 
    print("p = "+str(p))
    print("q = "+str(n//p))
# Out:
# 896
# p = 
# q = 
